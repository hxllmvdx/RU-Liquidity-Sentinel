# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from openpyxl import load_workbook

# %%
df1 = pd.read_excel('../../../data/raw/cbr/reserves/required_reserves_table.xlsx')
df1.drop(0, inplace=True)
df1.columns = df1.iloc[1]
df1 = df1.iloc[1:]
df1.reset_index(drop=True, inplace=True)
df1.rename(columns={df1.columns[0]: 'Период усреднения',
                    df1.columns[1]: 'Фактические среднедневные остатки средств на корсчетах',
                    df1.columns[2]: 'Обязательные резервы, подлежащие усреднению на корсчетах',
                    df1.columns[3]: 'Обязательные резервы на счетах для их учета',
                    df1.columns[4]: 'Количество кредитных организаций пользующихся правом усреднения обязательных резервов',
                    df1.columns[5]: 'Количество действующих кредитных организаций',
                    df1.columns[6]: 'Период усреднения обязательных резервов',
                    df1.columns[7]: 'Число календарных дней в периоде усреднения обязательных резервов',
                    df1.columns[8]: 'Отчетный период',
                    df1.columns[9]: 'Период регулирования обязательных резервов'
                    }, inplace=True)
df1.columns.name = None
df1.drop(df1.columns[6], axis=1, inplace=True)
first_col = df1.columns[0]
df1.head()

df1[first_col] = pd.to_datetime(df1[first_col], errors='coerce')

df1 = df1[df1[first_col].notna()]

df2 = pd.read_excel('../../../data/raw/cbr/ruonia/ruonia.xlsx')
df = pd.concat([df1, df2], axis=1)

df.head()

df.reset_index(drop=True, inplace=True)
df.to_csv('../../../data/processed/M1_dataset.csv',index=False)
# Out:
# c:\Users\mvhhg\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#   Фактические среднедневные остатки средств на корсчетах  \
# 0                      1970-01-01 00:00:00.000000195
# 1                      1970-01-01 00:00:00.000000231
# 2                      1970-01-01 00:00:00.000000282
# 3                      1970-01-01 00:00:00.000000368
# 4                      1970-01-01 00:00:00.000000356
#
#   Обязательные резервы, подлежащие усреднению на корсчетах  \
# 0                                                8.7
# 1                                                9.1
# 2                                               11.5
# 3                                                 12
# 4                                               12.7
#
#   Обязательные резервы на счетах для их учета  \
# 0                                         116
# 1                                       117.3
# 2                                       118.9
# 3                                       121.7
# 4                                       171.6
#
#   Количество кредитных организаций пользующихся правом усреднения обязательных резервов  \
# 0                                                492
# 1                                                503
# 2                                                521
# 3                                                523
# 4                                                650
#
#   Количество действующих кредитных организаций  \
# 0                                         1316
# 1                                         1315
# 2                                         1311
# 3                                         1304
# 4                                         1300
#
#   Число календарных дней в периоде усреднения обязательных резервов  \
# 0                                                 30
# 1                                                 31
# 2                                                 30
# 3                                                 31
# 4                                                 31
#
#            Отчетный период Период регулирования обязательных резервов  \
# 0  01.08.2004 — 01.09.2004                    03.09.2004 — 08.09.2004
# 1  01.09.2004 — 01.10.2004                    05.10.2004 — 08.10.2004
# 2  01.10.2004 — 01.11.2004                    03.11.2004 — 09.11.2004
# 3  01.11.2004 — 01.12.2004                    03.12.2004 — 08.12.2004
# 4  01.12.2004 — 01.01.2005                    13.01.2005 — 18.01.2005
#
#           DT    ruo     vol     T     C  MinRate  Percentile25  Percentile75  \
# 0 2026-05-07  14.07  975.17  91.0  24.0    13.30         14.00         14.10
# 1 2026-05-06  14.07  775.74  75.0  23.0    13.30         14.00         14.10
# 2 2026-05-05  14.19  668.34  63.0  20.0    13.40         14.10         14.20
# 3 2026-05-04  14.33  824.80  72.0  22.0    13.30         14.20         14.35
# 4 2026-04-30  14.49  880.14  83.0  20.0    14.25         14.35         14.50
#
#    MaxRate  StatusXML              DateUpdate
# 0    14.40        0.0 2026-05-08 14:22:33.630
# 1    14.30        0.0 2026-05-07 14:13:27.053
# 2    14.40        0.0 2026-05-06 14:24:19.780
# 3    14.45        0.0 2026-05-05 14:17:37.403
# 4    14.65        0.0 2026-05-04 14:20:43.437
